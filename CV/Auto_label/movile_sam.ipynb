# %%
# %cd /mnt/Investigate/Grounded-Segment-Anything

# %%
# !python3 ./EfficientSAM/grounded_mobile_sam.py

# %% [markdown]
# ## Investigate

# %%
# !python3 ./EfficientSAM/test.py

# %%
# !python3 ./EfficientSAM/test1.py
# Out:
# /mnt/Investigate/Grounded-Segment-Anything/GroundingDINO/groundingdino/models/GroundingDINO/ms_deform_attn.py:31: UserWarning: Failed to load custom C++ ops. Running on CPU mode Only!
#   warnings.warn("Failed to load custom C++ ops. Running on CPU mode Only!")
# 処理時間: 3.480791563168168秒
# ^C

# %% [markdown]
# ## Mobile-sam-onnx

# %%
# !python3 ./EfficientSAM/Mobile-sam-onnx.py
# Out:
# /mnt/Investigate/Grounded-Segment-Anything/GroundingDINO/groundingdino/models/GroundingDINO/ms_deform_attn.py:31: UserWarning: Failed to load custom C++ ops. Running on CPU mode Only!
#   warnings.warn("Failed to load custom C++ ops. Running on CPU mode Only!")
# LR SCALES: [0.08589934592000005, 0.10737418240000006, 0.13421772800000006, 0.1677721600000001, 0.20971520000000007, 0.2621440000000001, 0.3276800000000001, 0.4096000000000001, 0.5120000000000001, 0.6400000000000001, 0.8, 1.0]
# 処理時間: 20.517418222501874秒
# 処理時間: 22.22325959801674秒
# 処理時間: 17.303631111979485秒
# 処理時間: 18.99603577516973秒
# 処理時間: 17.800436845049262秒
# 処理時間: 18.904629396274686秒
# 処理時間: 20.20238295942545秒
# 処理時間: 18.005840323865414秒
# 処理時間: 15.293403754010797秒

# %% [markdown]
# ## Light-hq-sam

# %%
# !python3 ./EfficientSAM/Light-hq-sam-onnx.py

# %% [markdown]
# # https://github.com/nyoki-mtl/bert-mcts-youtube

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd ./drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# !git clone https://github.com/nyoki-mtl/bert-mcts-youtube.git
# Out:
# Cloning into 'bert-mcts-youtube'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 53 (delta 0), reused 0 (delta 0), pack-reused 39
# Unpacking objects: 100% (53/53), done.

# %%
# %cd bert-mcts-youtube
# Out:
# /content/drive/MyDrive/bert-mcts-youtube

# %%
# !pip install -r requirements.txt
# !python setup.py develop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 830 kB 34.7 MB/s
# ...
#      |████████████████████████████████| 5.3 MB 62.5 MB/s
# ...
#      |████████████████████████████████| 4.6 MB 65.9 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 829 kB 65.4 MB/s
# ...
#      |████████████████████████████████| 529 kB 72.9 MB/s
# ...
#      |████████████████████████████████| 163 kB 74.1 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 63.6 MB/s
# ...
#      |████████████████████████████████| 117 kB 76.3 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=b68d5ad51573ae009310a8a5e17ad72342a262857bbfd9bbf420792dec92b467
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# ...

# %% [markdown]
# **https://github.com/tttak/ShogiGokakuKyokumen**

# %%
# !mkdir data
# %cd data
# !git clone https://github.com/tttak/ShogiGokakuKyokumen.git
# Out:
# /content/drive/MyDrive/bert-mcts-youtube/data
# Cloning into 'ShogiGokakuKyokumen'...
# remote: Enumerating objects: 1777, done.
# remote: Counting objects: 100% (645/645), done.
# remote: Compressing objects: 100% (574/574), done.
# remote: Total 1777 (delta 92), reused 624 (delta 71), pack-reused 1132
# Receiving objects: 100% (1777/1777), 9.74 MiB | 9.71 MiB/s, done.
# Resolving deltas: 100% (322/322), done.
# Checking out files: 100% (2001/2001), done.

# %%
# !mkdir hcpe

# %%
# %cd -
# Out:
# /content/drive/MyDrive/bert-mcts-youtube

# %%
# !python tools/make_dataset.py
# Out:
#  72% 10511690/14534430 [07:47<02:52, 23325.90it/s]^C

# %%
# !pip uninstall torch
# Out:
# Found existing installation: torch 1.12.1+cu113
# Uninstalling torch-1.12.1+cu113:
#   Would remove:
#     /usr/local/bin/convert-caffe2-to-onnx
#     /usr/local/bin/convert-onnx-to-caffe2
#     /usr/local/bin/torchrun
#     /usr/local/lib/python3.7/dist-packages/caffe2/*
#     /usr/local/lib/python3.7/dist-packages/torch-1.12.1+cu113.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torch/*
#     /usr/local/lib/python3.7/dist-packages/torchgen/*
# Proceed (y/n)? y
#   Successfully uninstalled torch-1.12.1+cu113

# %%
# !pip uninstall torchvision
# Out:
# Found existing installation: torchvision 0.13.1+cu113
# Uninstalling torchvision-0.13.1+cu113:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/torchvision-0.13.1+cu113.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libcudart.053364c0.so.11.0
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libjpeg.ceea7512.so.62
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libnvjpeg.90286a3c.so.11
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libpng16.7f72a3c5.so.16
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libz.1328edc3.so.1
#     /usr/local/lib/python3.7/dist-packages/torchvision/*
# Proceed (y/n)? y
#   Successfully uninstalled torchvision-0.13.1+cu113

# %%
# !pip uninstall torchaudio
# Out:
# Found existing installation: torchaudio 0.12.1+cu113
# Uninstalling torchaudio-0.12.1+cu113:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/torchaudio-0.12.1+cu113.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torchaudio/*
# Proceed (y/n)? y
#   Successfully uninstalled torchaudio-0.12.1+cu113

# %%
# !pip install --upgrade torch==1.8.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 804.1 MB 2.8 kB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.9 requires torchvision>=0.8.2, which is not installed.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.8.1 which is incompatible.
# ...

# %%
# !pip install --upgrade torchtext==0.9.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 7.1 MB 28.1 MB/s
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.13.1
#     Uninstalling torchtext-0.13.1:
#       Successfully uninstalled torchtext-0.13.1
# ...

# %%
# !python tools/train.py configs/mlm_base.yaml
# Out:
# Global seed set to 42
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#
#   | Name  | Type    | Params
# ----------------------------------
# 0 | model | BertMLM | 86.1 M
# ----------------------------------
# 86.1 M    Trainable params
# 0         Non-trainable params
# 86.1 M    Total params
# 344.270   Total estimated model params size (MB)
# ...

# %%
# !python tools/pl_to_transformers.py work_dirs/mlm_base/version_0/checkpoints/last.ckpt

# %%
# !python tools/train.py /content/drive/MyDrive/bert-mcts-youtube/configs/policy_value_base.yaml
